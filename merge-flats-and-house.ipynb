# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.sample(5)
# Out:
#                                   property_name property_type  \
# 2380            3 BHK Flat in Sector 65 Gurgaon          flat
# 3619           2 BHK Flat in Sector 37D Gurgaon          flat
# 3052           3 BHK Flat in Sector 82A Gurgaon          flat
# 2764    2 Bedroom House for sale in DLF Phase 4         house
# 722   4 Bedroom House for sale in Surat Nagar 1         house
#
#                                society  price  price_per_sqft    area  \
# 2380                      m3m latitude   4.70         19747.0  2380.0
# 3619  signature global the millennia 3   0.45          7627.0   590.0
# 3052                    dlf the primus   1.85         10176.0  1818.0
# 2764                       independent   1.39         11583.0  1200.0
# 722                        independent   0.45         12162.0   370.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2380  Super Built up area 2380(221.11 sq.m.)Carpet a...        3         3
# ...

# %%
df.to_csv('final_properties.csv',index=False)
